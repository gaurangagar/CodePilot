# %%
from src.repository_load.repository_loader import repository_loader

docs=repository_loader("https://github.com/gaurangagar/Feedloop")

# %%
docs
# Out:
# [Document(metadata={'source': '.sampleenv', 'file_path': '.sampleenv', 'file_name': '.sampleenv', 'file_type': ''}, page_content='MONGODB_URI=""\r\nGOOGLE_ID=""\r\nGOOGLE_SECRET=""\r\nNEXTAUTH_SECRET=""\r\nRESEND_API_KEY=""\r\nGEMINI_API_KEY=""\r\nJWT_SECRET=""\r\nWEBSITE_URL=""'),
# ...

# %%
from src.utils.directory_tree import docs_to_tree
tree_structure = docs_to_tree(docs)

print(tree_structure)
# Out:
# ├── .sampleenv
# ├── README.md
# ├── components.json
# ├── emails
# │   ├── feedbackEmail.tsx
# │   └── insightEmail.tsx
# ├── eslint.config.mjs
# ├── next.config.ts
# ├── package.json
# ├── postcss.config.mjs
# ├── src
# │   ├── app
# │   │   ├── (client)
# │   │   │   ├── (auth)
# │   │   │   │   ├── sign-in
# │   │   │   │   │   └── page.jsx
# │   │   │   │   └── sign-up
# │   │   │   │       └── page.jsx
# │   │   │   ├── create-order
# │   │   │   │   └── page.jsx
# │   │   │   ├── dashboard
# │   │   │   │   └── page.jsx
# │   │   │   ├── feedback
# │   │   │   │   └── [id]
# │   │   │   │       └── page.jsx
# │   │   │   ├── order
# │   │   │   │   └── [orderid]
# │   │   │   │       └── page.jsx
# │   │   │   └── order-created
# │   │   │       └── Page.jsx
# │   │   ├── api
# │   │   │   ├── auth
# │   │   │   │   ├── [...nextauth]
# │   │   │   │   │   ├── options.ts
# │   │   │   │   │   └── route.ts
# │   │   │   │   ├── sign-in
# │   │   │   │   │   └── route.ts
# ...

# %%
import src.utils.directory_tree as dt

print(dt)
print(dir(dt))
# Out:
# <module 'src.utils.directory_tree' from 'c:\\Users\\HP\\Documents\\CodePilot\\src\\utils\\directory_tree.py'>
# ['Document', 'PurePosixPath', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_tree', 'build_file_tree', 'defaultdict', 'generate_repository_tree', 'tree_to_string']
